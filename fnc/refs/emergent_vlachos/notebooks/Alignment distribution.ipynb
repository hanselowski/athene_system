# %%
# %matplotlib inline

# %%
cd ../src
# Out:
# /Users/williamferreira/Dropbox/mscproject/src

# %%
from model.utils import get_aligned_data, get_dataset, get_hungarian_alignment_score_data
import pandas as pd
import pylab as pl

# %%
aligned_data = get_hungarian_alignment_score_data()

# %%
df_clean = get_dataset()

# %%
data = {}
for (c_id, a_id), alignment in aligned_data.items():
    stance = df_clean[df_clean.articleId == a_id].iloc[0]['articleHeadlineStance']
    data.setdefault(stance, []).append(alignment[1])

# %%
pd.DataFrame(data['for']).hist(bins=30, histtype='stepfilled', normed=True)
pl.suptitle("Alignment score distribution for stance: for")

# %%
pd.DataFrame(data['against']).hist(bins=30, histtype='stepfilled', normed=True)
pl.suptitle("Alignment score distribution for stance: against")

# %%
pd.DataFrame(data['observing']).hist(bins=30, histtype='stepfilled', normed=True)
pl.suptitle("Alignment score distribution for stance: observing")
